# %%
from helpers import *

# %%
df = df_it(np.random.randn(5, 4))

# %%
df
# Out:
#       0     1    2    3
# 0 -0.86 -0.88 0.50 1.25
# 1 -0.73  1.17 0.33 2.31
# 2 -0.65 -0.19 0.87 0.82
# 3  0.37  1.06 1.03 1.59
# 4 -0.93  0.76 0.55 0.55

# %%
df2 = style_df(df, {'td': 'font-size: 16px'})
df2
# Out:
# <style type="text/css">
# #T_6828a td {
#   font-size: 16px;
# }
# </style>
# <table id="T_6828a">
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_6828a_row0_col0" class="data row0 col0" >-0.86</td>
#       <td id="T_6828a_row0_col1" class="data row0 col1" >-0.88</td>
#       <td id="T_6828a_row0_col2" class="data row0 col2" >0.50</td>
#       <td id="T_6828a_row0_col3" class="data row0 col3" >1.25</td>
#     </tr>
#     <tr>
#       <td id="T_6828a_row1_col0" class="data row1 col0" >-0.73</td>
#       <td id="T_6828a_row1_col1" class="data row1 col1" >1.17</td>
#       <td id="T_6828a_row1_col2" class="data row1 col2" >0.33</td>
#       <td id="T_6828a_row1_col3" class="data row1 col3" >2.31</td>
#     </tr>
#     <tr>
#       <td id="T_6828a_row2_col0" class="data row2 col0" >-0.65</td>
#       <td id="T_6828a_row2_col1" class="data row2 col1" >-0.19</td>
#       <td id="T_6828a_row2_col2" class="data row2 col2" >0.87</td>
#       <td id="T_6828a_row2_col3" class="data row2 col3" >0.82</td>
#     </tr>
#     <tr>
#       <td id="T_6828a_row3_col0" class="data row3 col0" >0.37</td>
#       <td id="T_6828a_row3_col1" class="data row3 col1" >1.06</td>
#       <td id="T_6828a_row3_col2" class="data row3 col2" >1.03</td>
#       <td id="T_6828a_row3_col3" class="data row3 col3" >1.59</td>
#     </tr>
#     <tr>
#       <td id="T_6828a_row4_col0" class="data row4 col0" >-0.93</td>
#       <td id="T_6828a_row4_col1" class="data row4 col1" >0.76</td>
#       <td id="T_6828a_row4_col2" class="data row4 col2" >0.55</td>
#       <td id="T_6828a_row4_col3" class="data row4 col3" >0.55</td>
#     </tr>
#   </tbody>
# </table>

# %%
df3 = fancy_styles_df(df, bars = True, 
				align=0, 
				vmin=-2.5, 
				vmax=2.5, 
				cmap="YlOrRd", 
				height=50,
				width=60, 
				props="width:120px; border-right: 1px solid black;")

df3
# Out:
# <style type="text/css">
# #T_c4546_row0_col0 {
#   width: 120px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 19.7%, #fec05b 19.7%, #fec05b 30.0%, transparent 30.0%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_c4546_row0_col1 {
#   width: 120px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 19.4%, #fec35e 19.4%, #fec35e 30.0%, transparent 30.0%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_c4546_row0_col2 {
#   width: 120px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 30.0%, #fc5b2e 30.0%, #fc5b2e 36.0%, transparent 36.0%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_c4546_row0_col3 {
#   width: 120px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 30.0%, #e2191c 30.0%, #e2191c 45.1%, transparent 45.1%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_c4546_row1_col0 {
#   width: 120px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 21.3%, #feb953 21.3%, #feb953 30.0%, transparent 30.0%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_c4546_row1_col1 {
#   width: 120px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 30.0%, #e6211e 30.0%, #e6211e 44.0%, transparent 44.0%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_c4546_row1_col2 {
#   width: 120px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 30.0%, #fc6c33 30.0%, #fc6c33 33.9%, transparent 33.9%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_c4546_row1_col3 {
#   width: 120px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 30.0%, #910026 30.0%, #910026 57.7%, transparent 57.7%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_c4546_row2_col0 {
#   width: 120px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 22.3%, #feb44e 22.3%, #feb44e 30.0%, transparent 30.0%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_c4546_row2_col1 {
#   width: 120px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 27.7%, #fd9841 27.7%, #fd9841 30.0%, transparent 30.0%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_c4546_row2_col2 {
#   width: 120px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 30.0%, #f23924 30.0%, #f23924 40.4%, transparent 40.4%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_c4546_row2_col3 {
#   width: 120px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 30.0%, #f43d25 30.0%, #f43d25 39.9%, transparent 39.9%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_c4546_row3_col0 {
#   width: 120px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 30.0%, #fc6631 30.0%, #fc6631 34.5%, transparent 34.5%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_c4546_row3_col1 {
#   width: 120px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 30.0%, #ea2920 30.0%, #ea2920 42.7%, transparent 42.7%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_c4546_row3_col2 {
#   width: 120px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 30.0%, #ec2c21 30.0%, #ec2c21 42.4%, transparent 42.4%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_c4546_row3_col3 {
#   width: 120px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 30.0%, #ce0c22 30.0%, #ce0c22 49.1%, transparent 49.1%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_c4546_row4_col0 {
#   width: 120px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 18.9%, #fec561 18.9%, #fec561 30.0%, transparent 30.0%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_c4546_row4_col1 {
#   width: 120px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 30.0%, #f74327 30.0%, #f74327 39.1%, transparent 39.1%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_c4546_row4_col2 {
#   width: 120px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 30.0%, #fc572c 30.0%, #fc572c 36.6%, transparent 36.6%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_c4546_row4_col3 {
#   width: 120px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 30.0%, #fc552c 30.0%, #fc552c 36.7%, transparent 36.7%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# </style>
# <table id="T_c4546">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c4546_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_c4546_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_c4546_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_c4546_level0_col3" class="col_heading level0 col3" >3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c4546_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c4546_row0_col0" class="data row0 col0" >-0.857413</td>
#       <td id="T_c4546_row0_col1" class="data row0 col1" >-0.882627</td>
#       <td id="T_c4546_row0_col2" class="data row0 col2" >0.502065</td>
#       <td id="T_c4546_row0_col3" class="data row0 col3" >1.254372</td>
#     </tr>
#     <tr>
#       <th id="T_c4546_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c4546_row1_col0" class="data row1 col0" >-0.728374</td>
#       <td id="T_c4546_row1_col1" class="data row1 col1" >1.165300</td>
#       <td id="T_c4546_row1_col2" class="data row1 col2" >0.326893</td>
#       <td id="T_c4546_row1_col3" class="data row1 col3" >2.308075</td>
#     </tr>
#     <tr>
#       <th id="T_c4546_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c4546_row2_col0" class="data row2 col0" >-0.645080</td>
#       <td id="T_c4546_row2_col1" class="data row2 col1" >-0.193838</td>
#       <td id="T_c4546_row2_col2" class="data row2 col2" >0.866199</td>
#       <td id="T_c4546_row2_col3" class="data row2 col3" >0.823954</td>
#     </tr>
#     <tr>
#       <th id="T_c4546_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c4546_row3_col0" class="data row3 col0" >0.373936</td>
#       <td id="T_c4546_row3_col1" class="data row3 col1" >1.061070</td>
#       <td id="T_c4546_row3_col2" class="data row3 col2" >1.032554</td>
#       <td id="T_c4546_row3_col3" class="data row3 col3" >1.593170</td>
#     </tr>
#     <tr>
#       <th id="T_c4546_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c4546_row4_col0" class="data row4 col0" >-0.925157</td>
#       <td id="T_c4546_row4_col1" class="data row4 col1" >0.761354</td>
#       <td id="T_c4546_row4_col2" class="data row4 col2" >0.546832</td>
#       <td id="T_c4546_row4_col3" class="data row4 col3" >0.554898</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.style.background_gradient(cmap = 'YlOrRd').hide(axis = 'index').hide(axis = 'columns')
# Out:
# <style type="text/css">
# #T_04835_row0_col0 {
#   background-color: #fff8ba;
#   color: #000000;
# }
# #T_04835_row0_col1, #T_04835_row1_col2, #T_04835_row4_col0, #T_04835_row4_col3 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_04835_row0_col2 {
#   background-color: #fed977;
#   color: #000000;
# }
# #T_04835_row0_col3 {
#   background-color: #feab49;
#   color: #000000;
# }
# #T_04835_row1_col0 {
#   background-color: #ffe998;
#   color: #000000;
# }
# #T_04835_row1_col1, #T_04835_row1_col3, #T_04835_row3_col0, #T_04835_row3_col2 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# #T_04835_row2_col0 {
#   background-color: #fede82;
#   color: #000000;
# }
# #T_04835_row2_col1 {
#   background-color: #febe59;
#   color: #000000;
# }
# #T_04835_row2_col2 {
#   background-color: #df171d;
#   color: #f1f1f1;
# }
# #T_04835_row2_col3 {
#   background-color: #ffe997;
#   color: #000000;
# }
# #T_04835_row3_col1 {
#   background-color: #990026;
#   color: #f1f1f1;
# }
# #T_04835_row3_col3 {
#   background-color: #fc5f2f;
#   color: #f1f1f1;
# }
# #T_04835_row4_col1 {
#   background-color: #d30f20;
#   color: #f1f1f1;
# }
# #T_04835_row4_col2 {
#   background-color: #fec662;
#   color: #000000;
# }
# </style>
# <table id="T_04835">
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_04835_row0_col0" class="data row0 col0" >-0.857413</td>
#       <td id="T_04835_row0_col1" class="data row0 col1" >-0.882627</td>
#       <td id="T_04835_row0_col2" class="data row0 col2" >0.502065</td>
#       <td id="T_04835_row0_col3" class="data row0 col3" >1.254372</td>
#     </tr>
#     <tr>
#       <td id="T_04835_row1_col0" class="data row1 col0" >-0.728374</td>
#       <td id="T_04835_row1_col1" class="data row1 col1" >1.165300</td>
#       <td id="T_04835_row1_col2" class="data row1 col2" >0.326893</td>
#       <td id="T_04835_row1_col3" class="data row1 col3" >2.308075</td>
#     </tr>
#     <tr>
#       <td id="T_04835_row2_col0" class="data row2 col0" >-0.645080</td>
#       <td id="T_04835_row2_col1" class="data row2 col1" >-0.193838</td>
#       <td id="T_04835_row2_col2" class="data row2 col2" >0.866199</td>
#       <td id="T_04835_row2_col3" class="data row2 col3" >0.823954</td>
#     </tr>
#     <tr>
#       <td id="T_04835_row3_col0" class="data row3 col0" >0.373936</td>
#       <td id="T_04835_row3_col1" class="data row3 col1" >1.061070</td>
#       <td id="T_04835_row3_col2" class="data row3 col2" >1.032554</td>
#       <td id="T_04835_row3_col3" class="data row3 col3" >1.593170</td>
#     </tr>
#     <tr>
#       <td id="T_04835_row4_col0" class="data row4 col0" >-0.925157</td>
#       <td id="T_04835_row4_col1" class="data row4 col1" >0.761354</td>
#       <td id="T_04835_row4_col2" class="data row4 col2" >0.546832</td>
#       <td id="T_04835_row4_col3" class="data row4 col3" >0.554898</td>
#     </tr>
#   </tbody>
# </table>

# %%
fancy_styles_df(df,
				 background_gradient = True,
				 axis=None, 
				 vmin=0, 
				 vmax=2, 
				 cmap="RdYlBu")
# Out:
# <style type="text/css">
# #T_73471_row0_col0, #T_73471_row0_col1, #T_73471_row1_col0, #T_73471_row2_col0, #T_73471_row2_col1, #T_73471_row4_col0 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_73471_row0_col2 {
#   background-color: #f98e52;
#   color: #f1f1f1;
# }
# #T_73471_row0_col3 {
#   background-color: #d1ecf4;
#   color: #000000;
# }
# #T_73471_row1_col1 {
#   background-color: #e5f5ef;
#   color: #000000;
# }
# #T_73471_row1_col2 {
#   background-color: #e95538;
#   color: #f1f1f1;
# }
# #T_73471_row1_col3 {
#   background-color: #313695;
#   color: #f1f1f1;
# }
# #T_73471_row2_col2 {
#   background-color: #feea9f;
#   color: #000000;
# }
# #T_73471_row2_col3 {
#   background-color: #fee496;
#   color: #000000;
# }
# #T_73471_row3_col0 {
#   background-color: #ef633f;
#   color: #f1f1f1;
# }
# #T_73471_row3_col1 {
#   background-color: #f6fbd0;
#   color: #000000;
# }
# #T_73471_row3_col2 {
#   background-color: #fafdc9;
#   color: #000000;
# }
# #T_73471_row3_col3 {
#   background-color: #76afd2;
#   color: #f1f1f1;
# }
# #T_73471_row4_col1 {
#   background-color: #fed687;
#   color: #000000;
# }
# #T_73471_row4_col2 {
#   background-color: #fa9b58;
#   color: #000000;
# }
# #T_73471_row4_col3 {
#   background-color: #fba05b;
#   color: #000000;
# }
# </style>
# <table id="T_73471">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_73471_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_73471_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_73471_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_73471_level0_col3" class="col_heading level0 col3" >3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_73471_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_73471_row0_col0" class="data row0 col0" >-0.857413</td>
#       <td id="T_73471_row0_col1" class="data row0 col1" >-0.882627</td>
#       <td id="T_73471_row0_col2" class="data row0 col2" >0.502065</td>
#       <td id="T_73471_row0_col3" class="data row0 col3" >1.254372</td>
#     </tr>
#     <tr>
#       <th id="T_73471_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_73471_row1_col0" class="data row1 col0" >-0.728374</td>
#       <td id="T_73471_row1_col1" class="data row1 col1" >1.165300</td>
#       <td id="T_73471_row1_col2" class="data row1 col2" >0.326893</td>
#       <td id="T_73471_row1_col3" class="data row1 col3" >2.308075</td>
#     </tr>
#     <tr>
#       <th id="T_73471_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_73471_row2_col0" class="data row2 col0" >-0.645080</td>
#       <td id="T_73471_row2_col1" class="data row2 col1" >-0.193838</td>
#       <td id="T_73471_row2_col2" class="data row2 col2" >0.866199</td>
#       <td id="T_73471_row2_col3" class="data row2 col3" >0.823954</td>
#     </tr>
#     <tr>
#       <th id="T_73471_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_73471_row3_col0" class="data row3 col0" >0.373936</td>
#       <td id="T_73471_row3_col1" class="data row3 col1" >1.061070</td>
#       <td id="T_73471_row3_col2" class="data row3 col2" >1.032554</td>
#       <td id="T_73471_row3_col3" class="data row3 col3" >1.593170</td>
#     </tr>
#     <tr>
#       <th id="T_73471_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_73471_row4_col0" class="data row4 col0" >-0.925157</td>
#       <td id="T_73471_row4_col1" class="data row4 col1" >0.761354</td>
#       <td id="T_73471_row4_col2" class="data row4 col2" >0.546832</td>
#       <td id="T_73471_row4_col3" class="data row4 col3" >0.554898</td>
#     </tr>
#   </tbody>
# </table>

# %%
styler_dictionary = {
	'.col0, .col1, .col2' : 'background-color : red;\
	        color : yellow;\
			font-size : 18px;\
			width : 100px;\
			padding : 12px 12px 12px 12px',
	'.row1, .row3' : 'background-color: purple;\
					  color: white',
	'tbody' : 'border: 2px solid;',
	'td:hover': 'color: cyan;\
				text-align: center;\
				 font-weight: normal;\
				 background-color: blue'
}

# %%
style_df(df, styler_dictionary)
# Out:
# <style type="text/css">
# #T_9bb95 .col0 {
#   background-color: red;
#   color: yellow;
#   font-size: 18px;
#   width: 100px;
#   padding: 12px 12px 12px 12px;
# }
# #T_9bb95  .col1 {
#   background-color: red;
#   color: yellow;
#   font-size: 18px;
#   width: 100px;
#   padding: 12px 12px 12px 12px;
# }
# #T_9bb95  .col2 {
#   background-color: red;
#   color: yellow;
#   font-size: 18px;
#   width: 100px;
#   padding: 12px 12px 12px 12px;
# }
# #T_9bb95 .row1 {
#   background-color: purple;
#   color: white;
# }
# #T_9bb95  .row3 {
#   background-color: purple;
#   color: white;
# }
# #T_9bb95 tbody {
#   border: 2px solid;
# }
# #T_9bb95 td:hover {
#   color: cyan;
#   text-align: center;
#   font-weight: normal;
#   background-color: blue;
# }
# </style>
# <table id="T_9bb95">
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_9bb95_row0_col0" class="data row0 col0" >-0.86</td>
#       <td id="T_9bb95_row0_col1" class="data row0 col1" >-0.88</td>
#       <td id="T_9bb95_row0_col2" class="data row0 col2" >0.50</td>
#       <td id="T_9bb95_row0_col3" class="data row0 col3" >1.25</td>
#     </tr>
#     <tr>
#       <td id="T_9bb95_row1_col0" class="data row1 col0" >-0.73</td>
#       <td id="T_9bb95_row1_col1" class="data row1 col1" >1.17</td>
#       <td id="T_9bb95_row1_col2" class="data row1 col2" >0.33</td>
#       <td id="T_9bb95_row1_col3" class="data row1 col3" >2.31</td>
#     </tr>
#     <tr>
#       <td id="T_9bb95_row2_col0" class="data row2 col0" >-0.65</td>
#       <td id="T_9bb95_row2_col1" class="data row2 col1" >-0.19</td>
#       <td id="T_9bb95_row2_col2" class="data row2 col2" >0.87</td>
#       <td id="T_9bb95_row2_col3" class="data row2 col3" >0.82</td>
#     </tr>
#     <tr>
#       <td id="T_9bb95_row3_col0" class="data row3 col0" >0.37</td>
#       <td id="T_9bb95_row3_col1" class="data row3 col1" >1.06</td>
#       <td id="T_9bb95_row3_col2" class="data row3 col2" >1.03</td>
#       <td id="T_9bb95_row3_col3" class="data row3 col3" >1.59</td>
#     </tr>
#     <tr>
#       <td id="T_9bb95_row4_col0" class="data row4 col0" >-0.93</td>
#       <td id="T_9bb95_row4_col1" class="data row4 col1" >0.76</td>
#       <td id="T_9bb95_row4_col2" class="data row4 col2" >0.55</td>
#       <td id="T_9bb95_row4_col3" class="data row4 col3" >0.55</td>
#     </tr>
#   </tbody>
# </table>
