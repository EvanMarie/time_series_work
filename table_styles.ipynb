# %%
from helpers import * 
from sklearn.datasets import load_diabetes
import matplotlib as mpl
from tqdm.notebook import tqdm_notebook as tq
import time
# %matplotlib inline
plt.style.use('dark_blue_greens.mplstyle')
css_styling()
# Out:
# <style>
#
# a:link {
#     color: #1E3A4C !important;
#     font-weight: 600 !important;
# }
#
# /* visited link */
# a:visited {
#     color: #1E3A4C !important;
#     font-weight: 600 !important;
# }
#
# /* mouse over link */
# a:hover {
#     color: #1E3A4C !important;
#     font-weight: 600 !important;
# }
#
# /* selected link */
# a:active {
#     color: #1E3A4C !important;
#     font-weight: 600 !important;
# }
#
# </style>

# %%
df = df_it(np.random.randn(5, 4))

# %%
df
# Out:
#       0     1     2     3
# 0 -1.53 -0.35 -1.96 -0.44
# 1  1.33  0.14 -1.91 -1.01
# 2  0.12  0.06 -1.94 -1.02
# 3  0.36  1.74 -0.54 -0.53
# 4  0.03 -1.06  0.81  2.26

# %%
df.style.bar(align=0, 
			 vmin=-2.5, 
			 vmax=2.5, 
			 cmap="rainbow", 
			 height=50,
              width=60, 
			 props="width:120px; border-right: 1px solid black;")
# Out:
# <style type="text/css">
# #T_5c928_row0_col0 {
#   width: 120px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 11.6%, #1e91f3 11.6%, #1e91f3 30.0%, transparent 30.0%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_5c928_row0_col1 {
#   width: 120px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 25.8%, #5df9c7 25.8%, #5df9c7 30.0%, transparent 30.0%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_5c928_row0_col2 {
#   width: 120px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 6.5%, #4a53fb 6.5%, #4a53fb 30.0%, transparent 30.0%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_5c928_row0_col3 {
#   width: 120px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 24.7%, #52f5cb 24.7%, #52f5cb 30.0%, transparent 30.0%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_5c928_row1_col0 {
# ...

# %%
df.style.background_gradient(cmap = 'viridis')
# Out:
# <style type="text/css">
# #T_6693c_row0_col0, #T_6693c_row0_col2, #T_6693c_row1_col3, #T_6693c_row2_col3, #T_6693c_row4_col1 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_6693c_row0_col1 {
#   background-color: #3b528b;
#   color: #f1f1f1;
# }
# #T_6693c_row0_col3 {
#   background-color: #433d84;
#   color: #f1f1f1;
# }
# #T_6693c_row1_col0, #T_6693c_row3_col1, #T_6693c_row4_col2, #T_6693c_row4_col3 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_6693c_row1_col1 {
#   background-color: #277f8e;
#   color: #f1f1f1;
# }
# #T_6693c_row1_col2 {
#   background-color: #46075a;
#   color: #f1f1f1;
# }
# #T_6693c_row2_col0 {
#   background-color: #20a386;
#   color: #f1f1f1;
# }
# #T_6693c_row2_col1 {
#   background-color: #2a788e;
#   color: #f1f1f1;
# }
# #T_6693c_row2_col2 {
#   background-color: #450457;
#   color: #f1f1f1;
# }
# #T_6693c_row3_col0 {
#   background-color: #34b679;
#   color: #f1f1f1;
# }
# #T_6693c_row3_col2 {
#   background-color: #20938c;
# ...

# %%
styler_dictionary = {
	'.col0, .col1, .col2' : 'background-color : red;\
	        color : yellow;\
			font-size : 18px;\
			width : 100px;\
			padding : 12px 12px 12px 12px',
	'.row1, .row3' : 'background-color: purple;\
					  color: white',
	'tbody' : 'border: 2px solid;',
	'td:hover': 'color: cyan;\
				text-align: center;\
				 font-weight: normal;\
				 background-color: blue'
}

# %%
style_df(df, styler_dictionary)
# Out:
# <style type="text/css">
# #T_0fd1b .col0 {
#   background-color: red;
#   color: yellow;
#   font-size: 18px;
#   width: 100px;
#   padding: 12px 12px 12px 12px;
# }
# #T_0fd1b  .col1 {
#   background-color: red;
#   color: yellow;
#   font-size: 18px;
#   width: 100px;
#   padding: 12px 12px 12px 12px;
# }
# #T_0fd1b  .col2 {
#   background-color: red;
#   color: yellow;
#   font-size: 18px;
#   width: 100px;
#   padding: 12px 12px 12px 12px;
# }
# #T_0fd1b .row1 {
#   background-color: purple;
#   color: white;
# }
# #T_0fd1b  .row3 {
#   background-color: purple;
#   color: white;
# }
# #T_0fd1b tbody {
#   border: 2px solid;
# }
# #T_0fd1b td:hover {
#   color: cyan;
#   text-align: center;
#   font-weight: normal;
#   background-color: blue;
# }
# </style>
# <table id="T_0fd1b">
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_0fd1b_row0_col0" class="data row0 col0" >-1.53</td>
#       <td id="T_0fd1b_row0_col1" class="data row0 col1" >-0.35</td>
# ...
